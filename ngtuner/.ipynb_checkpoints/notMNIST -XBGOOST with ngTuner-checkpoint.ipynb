# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# standard libraries and classes
import os
import sys
import time
import string
import logging
import cProfile
import pstats
import pprint
import collections

from os import walk
from io import StringIO

# third party imports
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
import xgboost as xgb
import seaborn as sns


# frequently used classes

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import log_loss, accuracy_score, precision_score, recall_score, roc_auc_score
from IPython.core.debugger import Tracer
from IPython.display import display, Image
from functools import wraps
from datetime import datetime as dt
from pandas import DataFrame
from xgboost.sklearn import XGBClassifier
from scipy.stats import randint, uniform
from six.moves import cPickle as pickle
#from __future__ import print_function


# custom imports and settings

import helper_functions as hf
# %reload_ext autoreload
# %autoreload 2
# %reload_ext version_information
# %matplotlib inline
version_list = %version_information numpy, scipy, matplotlib, pandas, scikit-learn, xgboost, tensorflow
version_list_html= hf.dict_to_html(version_list.__dict__['packages'])
plt.rcParams['figure.figsize'] = (20,10)

# %%
# run_pickle = hf.pickler('runpickles/20170914/run_20170914225536')
# #pprint.pprint(run_pickle)
# context = run_pickle['run context']

# %%
context = hf.fetch_paths()
pickled = hf.pickler(context['pickle'], context, 'run context')
hf.objects_growth(context['summary'], 'Beginning Heap')
hf.write_dict({'Installed Versions':version_list.__dict__['packages']}, context['summary'], 'Software Versions')
hf.write_dict(context, context['summary'], 'Run time Context')
# Out:
# {'log path': 'logs/20171018/',
#  'model path': 'savedmodels/20171018/',
#  'modelpickles': 'savedmodels/20171018/pickled_20171018021137',
#  'pickle': 'runpickles/20171018/run_20171018021137',
#  'plot path': 'plots/20171018/run_021137/',
#  'run date': '20171018',
#  'run time': '021137',
#  'runprofiles path': 'runprofiles/20171018/',
#  'stats path': 'stats/20171018/',
#  'statsfile': 'stats/20171018/stats_20171018021137',
#  'summary': 'runprofiles/20171018/summary_20171018021137.txt'}

# %%
# Out:
# (15000,) (15000, 784)

# %%
#data = 'notMNIST50-15-15.pickle'
size = 50
image_size = 28
num_labels =  10
datasets, labels = hf.load_dataset('sample-notMNIST.pickle', context)
data_description =['Training Set', 'Validation Set', 'Test Set']
for i in range(len(datasets)):
    hf.show_random_samples(image_size ,datasets[i], labels[i], data_description[i], context, 5, num_labels)

# %%
estimator = XGBClassifier(
                        learning_rate = .01,
                        n_estimators = 5000,
                        max_depth = 3,
                        min_child_weight=1,
                        gamma = 0,
                        subsample = 0.7,
                        colsample_bytree = 0.7,
                        objective= 'multi:softmax',
                        reg_alpha = 0.001,
                        seed=27)

# %%
initial_result = hf.modelfit(estimator, datasets, labels, context, 'merror',interval =100,early_stopping_rounds=100, num_labels = num_labels, cv_folds=5)
# Out:
# Average=  [[ 0.24366  0.25854  0.188  ]]
# High Bias
# {'base_score': 0.5,
#  'colsample_bylevel': 1.0,
#  'colsample_bytree': 0.9,
#  'gamma': 0.0,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 7,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.001,
#  'reg_lambda': 1.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.78}
# Average=  [[ 0.09059  0.17582  0.1047 ]]
# tuned
# {'base_score': 0.5,
#  'colsample_bylevel': 1.0,
#  'colsample_bytree': 0.9,
#  'gamma': 0.0,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 7,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.001,
#  'reg_lambda': 1.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.78}
# Average=  [[ 0.05558  0.15778  0.0912 ]]
# High Variance
# {'base_score': 0.5,
#  'colsample_bylevel': 0.58,
#  'colsample_bytree': 0.49,
#  'gamma': 0.13,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 3,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.10000000000000001,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.46}
# Average=  [[ 0.05686  0.1559   0.08916]]
# tuned
# {'base_score': 0.5,
#  'colsample_bylevel': 0.58,
#  'colsample_bytree': 0.49,
#  'gamma': 0.13,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 3,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.10000000000000001,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.46}
# Average=  [[ 0.05626  0.15336  0.08708]]
# tuned
# {'base_score': 0.5,
#  'colsample_bylevel': 0.58,
#  'colsample_bytree': 0.49,
#  'gamma': 0.13,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 3,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.10000000000000001,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.46}
# Average=  [[ 0.05452  0.15136  0.08518]]
# tuned
# {'base_score': 0.5,
#  'colsample_bylevel': 0.58,
#  'colsample_bytree': 0.49,
#  'gamma': 0.13,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 3,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.10000000000000001,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.46}
# Average=  [[ 0.05276  0.14946  0.08336]]
# tuned
# {'base_score': 0.5,
#  'colsample_bylevel': 0.58,
#  'colsample_bytree': 0.49,
#  'gamma': 0.13,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 3,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.10000000000000001,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.46}
# Average=  [[ 0.05086  0.1477   0.0817 ]]
# tuned
# {'base_score': 0.5,
#  'colsample_bylevel': 0.58,
#  'colsample_bytree': 0.49,
#  'gamma': 0.13,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 3,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.10000000000000001,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.46}
# Average=  [[ 0.04893  0.1459   0.08056]]
# tuned
# {'base_score': 0.5,
#  'colsample_bylevel': 0.58,
#  'colsample_bytree': 0.49,
#  'gamma': 0.13,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 3,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.10000000000000001,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.46}
# Average=  [[ 0.04693  0.1448   0.07948]]
# tuned
# {'base_score': 0.5,
#  'colsample_bylevel': 0.58,
#  'colsample_bytree': 0.49,
#  'gamma': 0.13,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 3,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.10000000000000001,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.46}
# Average=  [[ 0.04507  0.14342  0.07864]]
# tuned
# {'base_score': 0.5,
#  'colsample_bylevel': 0.58,
#  'colsample_bytree': 0.49,
#  'gamma': 0.13,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 3,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.10000000000000001,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.46}
# Average=  [[ 0.04319  0.1425   0.07818]]
# tuned
# {'base_score': 0.5,
#  'colsample_bylevel': 0.58,
#  'colsample_bytree': 0.49,
#  'gamma': 0.13,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 3,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.10000000000000001,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.46}
# Average=  [[ 0.04146  0.1417   0.07736]]
# High Variance
# {'base_score': 0.5,
#  'colsample_bylevel': 0.55,
#  'colsample_bytree': 0.41,
#  'gamma': 0.67,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 2,
#  'min_child_weight': 12,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.10000000000000001,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.44}
# Average=  [[ 0.04099  0.14136  0.0772 ]]
# High Variance
# {'base_score': 0.5,
#  'colsample_bylevel': 0.44,
#  'colsample_bytree': 0.4,
#  'gamma': 0.89,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 1,
#  'min_child_weight': 13,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 10.0,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.4}
#
# Model Report
# Accuracy : 0.89810
# Optimal Boosters : 1399

# %%
initial_result = hf.modelfit(estimator, datasets, labels, context, 'merror',interval =75,early_stopping_rounds=100, num_labels = num_labels, cv_folds=5)
# Out:
# Average=  [[ 0.2522   0.26418  0.1946 ]]
# High Bias
# {'base_score': 0.5,
#  'colsample_bylevel': 1.0,
#  'colsample_bytree': 0.9,
#  'gamma': 0.0,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 7,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 1399,
#  'num_class': 10,
#  'objective': 'multi:softprob',
#  'reg_alpha': 0.001,
#  'reg_lambda': 1.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.78}
# Average=  [[ 0.10152  0.18078  0.10912]]
# High Bias
# {'base_score': 0.5,
#  'colsample_bylevel': 1.0,
#  'colsample_bytree': 0.92,
#  'gamma': 0.0,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 13,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 1399,
#  'num_class': 10,
#  'objective': 'multi:softprob',
#  'reg_alpha': 0.001,
#  'reg_lambda': 1.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.87}
# Average=  [[ 0.04558  0.16126  0.0926 ]]
# High Variance
# {'base_score': 0.5,
#  'colsample_bylevel': 0.42,
#  'colsample_bytree': 0.53,
#  'gamma': 0.55,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 7,
#  'min_child_weight': 3,
#  'missing': None,
#  'n_estimators': 1399,
#  'num_class': 10,
#  'objective': 'multi:softprob',
#  'reg_alpha': 0.01,
#  'reg_lambda': 1.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.62}
# Average=  [[ 0.04258  0.1549   0.08718]]
# High Variance
# {'base_score': 0.5,
#  'colsample_bylevel': 0.41,
#  'colsample_bytree': 0.41,
#  'gamma': 0.83,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 2,
#  'min_child_weight': 9,
#  'missing': None,
#  'n_estimators': 1399,
#  'num_class': 10,
#  'objective': 'multi:softprob',
#  'reg_alpha': 0.01,
#  'reg_lambda': 1.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.49}
# Average=  [[ 0.0454   0.15588  0.08796]]
# High Variance
# {'base_score': 0.5,
#  'colsample_bylevel': 0.4,
#  'colsample_bytree': 0.4,
#  'gamma': 0.96,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 1,
#  'min_child_weight': 14,
#  'missing': None,
#  'n_estimators': 1399,
#  'num_class': 10,
#  'objective': 'multi:softprob',
#  'reg_alpha': 1.0,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.47}
#
# Model Report
# Accuracy : 0.84710
# Optimal Boosters : 299

# %%
initial_result = hf.modelfit(estimator, datasets, labels, context, 'merror',interval =100,early_stopping_rounds=100, num_labels = num_labels, cv_folds=5)
# Out:
# Average=  [[ 0.24366  0.25854  0.188  ]]
# High Bias
# {'base_score': 0.5,
#  'colsample_bylevel': 1.0,
#  'colsample_bytree': 0.9,
#  'gamma': 0.0,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 7,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 299,
#  'num_class': 10,
#  'objective': 'multi:softprob',
#  'reg_alpha': 0.001,
#  'reg_lambda': 1.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.78}
# Average=  [[ 0.09059  0.17582  0.1047 ]]
# High Bias
# {'base_score': 0.5,
#  'colsample_bylevel': 1.0,
#  'colsample_bytree': 0.92,
#  'gamma': 0.0,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 13,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 299,
#  'num_class': 10,
#  'objective': 'multi:softprob',
#  'reg_alpha': 0.001,
#  'reg_lambda': 1.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.87}
#
# Model Report
# Accuracy : 0.84710
# Optimal Boosters : 299

# %%
#switched to larger 50-15-15K dataset

initial_result = hf.modelfit(estimator, datasets, labels, context, 'merror',
                             interval =75,
                             early_stopping_rounds=100, 
                             num_labels = num_labels, 
                             cv_folds=5)
# Out:
# Average=  [[ 0.252256   0.2625468  0.1927868]]
# High Bias
# {'base_score': 0.5,
#  'colsample_bylevel': 1.0,
#  'colsample_bytree': 0.76,
#  'gamma': 0.0,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.001,
#  'reg_lambda': 0.01,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.77}
# Average=  [[ 0.192392   0.2090932  0.1381466]]
# High Bias
# {'base_score': 0.5,
#  'colsample_bylevel': 1.0,
#  'colsample_bytree': 0.93,
#  'gamma': 0.0,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 12,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.001,
#  'reg_lambda': 0.001,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.88}
# Average=  [[ 0.045828   0.1514     0.0851068]]
# High Variance
# {'base_score': 0.5,
#  'colsample_bylevel': 0.68,
#  'colsample_bytree': 0.86,
#  'gamma': 0.45,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 6,
#  'min_child_weight': 4,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 10.0,
#  'reg_lambda': 0.10000000000000001,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.7}
# Average=  [[ 0.049504   0.14788    0.0823866]]
# High Variance
# {'base_score': 0.5,
#  'colsample_bylevel': 0.5,
#  'colsample_bytree': 0.72,
#  'gamma': 0.53,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 5,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 10.0,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.62}
# Average=  [[ 0.052648   0.1471732  0.0817468]]
# High Bias
# {'base_score': 0.5,
#  'colsample_bylevel': 0.98,
#  'colsample_bytree': 0.79,
#  'gamma': 0.18,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 7,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.01,
#  'reg_lambda': 0.01,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.99}
# Average=  [[ 0.042504   0.1385332  0.075613 ]]
# High Variance
# {'base_score': 0.5,
#  'colsample_bylevel': 0.97,
#  'colsample_bytree': 0.52,
#  'gamma': 0.93,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 1,
#  'min_child_weight': 5,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.01,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.78}
# Average=  [[ 0.043528   0.1387734  0.0760532]]
# High Variance
# {'base_score': 0.5,
#  'colsample_bylevel': 0.46,
#  'colsample_bytree': 0.41,
#  'gamma': 0.93,
#  'learning_rate': 0.01,
#  'max_delta_step': 0,
#  'max_depth': 1,
#  'min_child_weight': 5,
#  'missing': None,
#  'n_estimators': 5000,
#  'num_class': 10,
#  'objective': 'multi:softmax',
#  'reg_alpha': 1.0,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.5}
#
# Model Report
# Accuracy : 0.86427
# Optimal Boosters : 464

# %%
initial_result = hf.modelfit(estimator, datasets, labels, context, 'merror',
                             #interval =75,
                             early_stopping_rounds=100, 
                             num_labels = num_labels, 
                             cv_folds=5)

# %%
pprint.pprint(initial_result)
# Out:
# {'accuracy plot': 'plots/20171016/run_170954/210853.png',
#  'model results': {'Test Accuracy': 0.88,
#                    'Train Accuracy': 0.996,
#                    'Validation Accuracy': 0.81000000000000005},
#  'optimal parameters': {'base_score': 0.5,
#                         'colsample_bylevel': 1,
#                         'colsample_bytree': 0.7,
#                         'gamma': 0,
#                         'learning_rate': 0.3,
#                         'max_delta_step': 0,
#                         'max_depth': 3,
#                         'min_child_weight': 1,
#                         'missing': None,
#                         'n_estimators': 21,
#                         'objective': 'multi:softprob',
#                         'reg_alpha': 0.001,
#                         'reg_lambda': 1,
#                         'scale_pos_weight': 1,
#                         'seed': 27,
#                         'silent': 1,
#                         'subsample': 0.7},
#  'run context': {'log path': 'logs/20171016/',
#                  'model path': 'savedmodels/20171016/',
#                  'modelpickles': 'savedmodels/20171016/pickled_20171016170954',
#                  'pickle': 'runpickles/20171016/run_20171016170954',
#                  'plot path': 'plots/20171016/run_170954/',
#                  'run date': '20171016',
#                  'run time': '170954',
#                  'runprofiles path': 'runprofiles/20171016/',
#                  'stats path': 'stats/20171016/',
#                  'statsfile': 'stats/20171016/stats_20171016170954',
#                  'summary': 'runprofiles/20171016/summary_20171016170954.txt'},
#  'run results': {'Test Accuracy': 0.88,
#                  'Train Accuracy': 0.996,
#                  'Validation Accuracy': 0.81000000000000005}}

# %%
result = initial_result['model results']
parameters =initial_result['optimal parameters']
pprint.pprint(parameters)
# Out:
# {'base_score': 0.5,
#  'colsample_bylevel': 1,
#  'colsample_bytree': 0.7,
#  'gamma': 0,
#  'learning_rate': 0.3,
#  'max_delta_step': 0,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 13,
#  'objective': 'multi:softmax',
#  'reg_alpha': 0.001,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.7}

# %%
def meter(result, context,threshold = 0.05, human_accuracy = 1.0):
    train_accuracy = result[0]
    valid_accuracy = result[1]
    test_accuracy = result[2]
    
    

    bias = abs(human_accuracy - train_accuracy)
    variance = abs(valid_accuracy - train_accuracy)

    if bias < threshold:
        if variance < threshold:
           return('tuned') 
        else:
            return('High Variance')
    else:
        return('High Bias')

# %%
diagnosis = meter(result, context)
print(diagnosis)

#pprint.pprint(parameters)
parameters = tuner(diagnosis, parameters, context)
# Out:
# High Variance
# {'base_score': 0.5,
#  'colsample_bylevel': 0.4,
#  'colsample_bytree': 0.4,
#  'gamma': 0.99,
#  'learning_rate': 0.3,
#  'max_delta_step': 0,
#  'max_depth': 1,
#  'min_child_weight': 14,
#  'missing': None,
#  'n_estimators': 13,
#  'objective': 'multi:softmax',
#  'reg_alpha': 10.0,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.4}
# {'base_score': 0.5,
#  'colsample_bylevel': 0.4,
#  'colsample_bytree': 0.4,
#  'gamma': 0.99,
#  'learning_rate': 0.3,
#  'max_delta_step': 0,
#  'max_depth': 1,
#  'min_child_weight': 14,
#  'missing': None,
#  'n_estimators': 13,
#  'objective': 'multi:softmax',
#  'reg_alpha': 10.0,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1,
#  'seed': 27,
#  'silent': 1,
#  'subsample': 0.4}

# %%
def tuner(diagnosis, in_parameters, context):
    out_parameters = in_parameters.copy()
    
    if diagnosis == 'High Variance':
    
        #'colsample_bylevel' - reduce value to increase regularization
        left = min(parameter_ranges['colsample_bylevel']) *100 
        right = in_parameters['colsample_bylevel'] *100 
        
        if left == right:
            new_value = left
        else:
            new_value = np.random.randint(left,right) 
        
        out_parameters.update({'colsample_bylevel': new_value/100})
    
        #'colsample_bytree' - reduce value to increase regularization
        left = min(parameter_ranges['colsample_bytree']) *100 
        right = in_parameters['colsample_bytree'] *100 
        
        if left == right:
            new_value = left
        else:
            new_value = np.random.randint(left,right) 
        
        out_parameters.update({'colsample_bytree': new_value/100})
    
        #'subsample' - reduce value to increase regularization
        left = min(parameter_ranges['subsample']) *100 
        right = in_parameters['subsample'] *100 
        
        if left == right:
            new_value = left
        else:
            new_value = np.random.randint(left,right) 
        
        out_parameters.update({'subsample': new_value/100})
        
        #'max_depth' - reduce value to decrease model complexity
        left = min(parameter_ranges['max_depth']) 
        right = in_parameters['max_depth'] 
        
        if left == right:
            new_value = left
        else:
            new_value = np.random.randint(left,right) 

        out_parameters.update({'max_depth': new_value})
        
        #'min_child_weight' - increase to reduce model complexity
        left = in_parameters['min_child_weight'] 
        right = max(parameter_ranges['min_child_weight']) 
        
        if left == right:
            new_value = left
        else:
            new_value = np.random.randint(left,right) 
            
        out_parameters.update({'min_child_weight': new_value})
        
        #'gamma' - increase to reduce model complexity
        left = in_parameters['gamma']  * 100 
        right = max(parameter_ranges['gamma']) *100 
        
        if left == right:
            new_value = left
        else:
            new_value = np.random.randint(left,right)  
        
        out_parameters.update({'gamma': new_value/100})
        
        #'alpha' - increase to reduce model complexity
        left =  (np.log10(1.0 / in_parameters['reg_alpha']) * -1) 
        right = max(parameter_ranges['reg_alpha']) 
        
        if left == right:
            new_value = np.power(10, float(left))
        else:
            new_value = np.power(10, float(np.random.randint(left,right)))
        
        
        new_value = round(new_value, 4)
        out_parameters.update({'reg_alpha':new_value})
        
        #'lambda' - increase to reduce model complexity
        left =  (np.log10(1.0 / in_parameters['reg_lambda']) * -1) 
        right = max(parameter_ranges['reg_lambda']) 
        
        if left == right:
            new_value = np.power(10, float(left))
        else:
            new_value = np.power(10, float(np.random.randint(left,right)))
        

        out_parameters.update({'reg_lambda': round(new_value,4)})
    
    
    if diagnosis == 'High Bias':
    
        #'colsample_bylevel' - increase value to reduce regularization
        left = in_parameters['colsample_bylevel'] *100 
        right = max(parameter_ranges['colsample_bylevel']) *100 +1
        
        if left == right:
            new_value = left
        else:
            new_value = np.random.randint(left,right) 
        

        out_parameters.update({'colsample_bylevel': new_value/100})
    
        #'colsample_bytree' - increase value to reduce regularization
        left = in_parameters['colsample_bytree'] *100 
        right = max(parameter_ranges['colsample_bytree']) *100 +1
        
        if left == right:
            new_value = left
        else:
            new_value = np.random.randint(left,right) 

        out_parameters.update({'colsample_bytree': new_value/100})
    
        #'subsample' - increase value to reduce regularization
        left = in_parameters['subsample'] *100 
        right = max(parameter_ranges['subsample']) *100 +1
        
        if left == right:
            new_value = left
        else:
            new_value = np.random.randint(left,right) 
        
        out_parameters.update({'subsample': new_value/100})
        
        #'max_depth' - increase value to increase model complexity
        left = in_parameters['max_depth'] 
        right = max(parameter_ranges['max_depth']) +1
        
        if left == right:
            new_value = left
        else:
            new_value = np.random.randint(left,right) 
        
        out_parameters.update({'max_depth': new_value})
        
        #'min_child_weight' - decrease to increase model complexity
        right = in_parameters['min_child_weight'] 
        left = min(parameter_ranges['min_child_weight'])
        
        if left == right:
            new_value = left
        else:
            new_value = np.random.randint(left,right) 

        out_parameters.update({'min_child_weight': new_value})
        
        #'gamma' - reduce to increase model complexity
        right = in_parameters['gamma']  * 100 
        left = min(parameter_ranges['gamma']) *100 
        
        if left == right:
            new_value = left
        else:
            new_value = np.random.randint(left,right) 
        
        out_parameters.update({'gamma': new_value/100 })
        
        #'alpha' - decrease to increase model complexity
        right =  (np.log10(1.0 / in_parameters['reg_alpha']) * -1) + 1 
        left = min(parameter_ranges['reg_alpha']) 
        
        if left == right:
            new_value = np.power(10, left)
        else:
            new_value = np.power(10, float(np.random.randint(left,right)))
        
        new_value = round(new_value, 4)
        out_parameters.update({'reg_alpha':new_value})
        
        #'lambda' - decrease to reduce model complexity
        right =  (np.log10(1.0 / in_parameters['reg_lambda']) * -1) + 1 
        left = min(parameter_ranges['reg_lambda']) 
        
        if left == right:
            new_value = np.power(10, left)
        else:
            new_value = np.power(10, float(np.random.randint(left,right)))
        
        out_parameters.update({'reg_lambda': round(new_value,4)})
        

    pprint.pprint(in_parameters)
    pprint.pprint(out_parameters)
    
    return out_parameters

# %%
parameter_ranges = {
    'colsample_bylevel': [0.4, 1.0],
    'colsample_bytree': [0.4, 1.0],
    'subsample': [0.4, 1.0],

    'learning_rate': [0, 1],
    'n_estimators': [15, 1000],
    
    'max_depth': [1,15],
    'min_child_weight': [1,15],
    'gamma': [0, 1],

    'reg_alpha': [-3,2],   #powers of 10
    'reg_lambda': [-3,2]}  #powers of 10

# %%
in_parameters = parameters
left = in_parameters['min_child_weight'] 
right = max(parameter_ranges['min_child_weight']) 
        
# if left == right:
#     new_value = left
# else:
#     new_value = np.random.randint(left,right) 

print(left,right)
# Out:
# 16 15

# %%
x=0.00001000000000001
y = round(float(x),5)
print(y)
# Out:
# 1e-05

# %%
tuning_rounds = 3
tuner_params =[{'max_depth':[3,6,9], 'min_child_weight':[3,6,9]},
            {'gamma':[.2,.5,.8]},
            {'subsample':[.3, .6, .9], 'colsample_bytree':[.3,.6,.9]},
            {'reg_lambda':[3, 6, 9] }]

for i in range(len(tuner_params)):
    pickled = hf.pickler(context['pickle'])
    parameters = pickled['optimal parameters']
    estimator = XGBClassifier(**parameters)
    
    final_result = hf.tuner_cv(estimator, datasets[0], labels[0], datasets[1], labels[1], 
                               tuner_params[i], tuning_rounds, steps, 
                               allowed_ranges, context, cv=3)
# Out:
# Current Iteration  {'min_child_weight': 3, 'max_depth': 6}  CV Accuracy  0.744  Validation Accuracy  0.83
# parameter min_child_weight
# result: 3  step: 1  allowed_range: [1, 10]  seen: [3.0, 6.0, 9.0]
# [2, 4]
# parameter max_depth
# result: 6  step: 1  allowed_range: [1, 10]  seen: [3.0, 6.0, 9.0]
# [5, 7]
# Extended List : {'min_child_weight': [2, 4], 'max_depth': [5, 7]}
# -------------------------------
# Current Iteration  {'min_child_weight': 2, 'max_depth': 5}  CV Accuracy  0.756  Validation Accuracy  0.81
# parameter min_child_weight
# result: 2  step: 1  allowed_range: [1, 10]  seen: [3.0, 6.0, 9.0, 2.0, 4.0]
# []
# parameter max_depth
# result: 5  step: 1  allowed_range: [1, 10]  seen: [3.0, 6.0, 9.0, 5.0, 7.0]
# [4]
# Extended List : {'min_child_weight': [2], 'max_depth': [4]}
# -------------------------------
# Current Iteration  {'min_child_weight': 2, 'max_depth': 4}  CV Accuracy  0.75  Validation Accuracy  0.82
# parameter min_child_weight
# result: 2  step: 1  allowed_range: [1, 10]  seen: [3.0, 6.0, 9.0, 2.0, 4.0]
# []
# parameter max_depth
# result: 4  step: 1  allowed_range: [1, 10]  seen: [3.0, 6.0, 9.0, 5.0, 7.0, 4.0]
# []
# Extended List : {'min_child_weight': [2], 'max_depth': [4]}
# -------------------------------
# Current Iteration  {'gamma': 0.8}  CV Accuracy  0.746  Validation Accuracy  0.78
# parameter gamma
# result: 0.8  step: 0.1  allowed_range: [0, 1]  seen: [0.2, 0.5, 0.8]
# [0.7, 0.9]
# Extended List : {'gamma': [0.7, 0.9]}
# -------------------------------
# Current Iteration  {'gamma': 0.7}  CV Accuracy  0.74  Validation Accuracy  0.79
# parameter gamma
# result: 0.7  step: 0.1  allowed_range: [0, 1]  seen: [0.2, 0.5, 0.8, 0.7, 0.9]
# [0.6]
# Extended List : {'gamma': [0.6]}
# -------------------------------
# Current Iteration  {'gamma': 0.6}  CV Accuracy  0.742  Validation Accuracy  0.78
# parameter gamma
# result: 0.6  step: 0.1  allowed_range: [0, 1]  seen: [0.2, 0.5, 0.8, 0.7, 0.9, 0.6]
# []
# Extended List : {'gamma': [0.6]}
# -------------------------------
# Current Iteration  {'subsample': 0.6, 'colsample_bytree': 0.3}  CV Accuracy  0.76  Validation Accuracy  0.79
# parameter subsample
# result: 0.6  step: 0.05  allowed_range: [0, 1]  seen: [0.3, 0.6, 0.9]
# [0.55, 0.65]
# parameter colsample_bytree
# result: 0.3  step: 0.05  allowed_range: [0, 1]  seen: [0.3, 0.6, 0.9]
# [0.25, 0.35]
# Extended List : {'subsample': [0.55, 0.65], 'colsample_bytree': [0.25, 0.35]}
# -------------------------------
# Current Iteration  {'subsample': 0.65, 'colsample_bytree': 0.25}  CV Accuracy  0.748  Validation Accuracy  0.79
# parameter subsample
# result: 0.65  step: 0.05  allowed_range: [0, 1]  seen: [0.3, 0.6, 0.9, 0.55, 0.65]
# [0.7]
# parameter colsample_bytree
# result: 0.25  step: 0.05  allowed_range: [0, 1]  seen: [0.3, 0.6, 0.9, 0.25, 0.35]
# [0.2]
# Extended List : {'subsample': [0.7], 'colsample_bytree': [0.2]}
# -------------------------------
# Current Iteration  {'subsample': 0.7, 'colsample_bytree': 0.2}  CV Accuracy  0.736  Validation Accuracy  0.83
# parameter subsample
# result: 0.7  step: 0.05  allowed_range: [0, 1]  seen: [0.3, 0.6, 0.9, 0.55, 0.65, 0.7]
# [0.75]
# parameter colsample_bytree
# result: 0.2  step: 0.05  allowed_range: [0, 1]  seen: [0.3, 0.6, 0.9, 0.25, 0.35, 0.2]
# [0.15]
# Extended List : {'subsample': [0.75], 'colsample_bytree': [0.15]}
# -------------------------------
# Current Iteration  {'reg_lambda': 3}  CV Accuracy  0.746  Validation Accuracy  0.82
# parameter reg_lambda
# result: 3  step: 0.25  allowed_range: [1, 10]  seen: [3.0, 6.0, 9.0]
# [2.75, 3.25]
# Extended List : {'reg_lambda': [2.75, 3.25]}
# -------------------------------
# Current Iteration  {'reg_lambda': 3.25}  CV Accuracy  0.74  Validation Accuracy  0.82
# parameter reg_lambda
# result: 3.25  step: 0.25  allowed_range: [1, 10]  seen: [3.0, 6.0, 9.0, 2.75, 3.25]
# [3.5]
# Extended List : {'reg_lambda': [3.5]}
# -------------------------------
# Current Iteration  {'reg_lambda': 3.5}  CV Accuracy  0.75  Validation Accuracy  0.83
# parameter reg_lambda
# result: 3.5  step: 0.25  allowed_range: [1, 10]  seen: [3.0, 6.0, 9.0, 2.75, 3.25, 3.5]
# [3.75]
# Extended List : {'reg_lambda': [3.75]}
# -------------------------------

# %%
# Now tune reg_alpha
best_alpha ={}
pickled = hf.pickler(context['pickle'])
parameters = pickled['optimal parameters']
param_test = {'reg_alpha':[0, 0.001, 0.005, 0.01, 0.05] }

estimator = XGBClassifier(**parameters)

gsearch_alpha = GridSearchCV(estimator = estimator, 
                        param_grid = param_test, 
                        scoring= 'accuracy',
                        n_jobs= -1,
                        cv= 3)
optimal_alpha = gsearch_alpha.fit(datasets[0],labels[0])
gs_plot = hf.plot_grid_search(optimal_alpha, param_test, context)

#print('Best parameter', optimal_alpha.best_params_, 'CV Accuracy: ', optimal_alpha.best_score_)
# Update the parameters list with best scoring parameter
parameters.update({k: optimal_alpha.best_params_[k] for k in optimal_alpha.best_params_})


# Update the pickle
updated_pickle = hf.pickler(context['pickle'], parameters, 'optimal parameters')

# Write to summary file
best_alpha.update({'Chosen:':str(optimal_alpha.best_params_) + ' CV Score:' + str(optimal_alpha.best_score_)})   
hf.write_dict(best_alpha, context['summary'],'alpha Grid Search Result')
# Out:
# {'Chosen:': "{'reg_alpha': 0} CV Score:0.75"}

# %%
# Now lower learning rate and find optimal number of boosters
pickled = hf.pickler(context['pickle'])
parameters = pickled['optimal parameters']
parameters.update({'n_estimators': 5000})
parameters.update({'learning_rate': 0.01})

final_tuner = tree_tuner = XGBClassifier(**parameters)

optimal_model = hf.modelfit(final_tuner, datasets, labels, context, 'merror', num_labels = num_labels, cv_folds=5)
# Out:
# Model Report
# Accuracy : 0.85000
# Optimal Boosters : 44

# %%
#End Heap
hf.objects_growth(context['summary'], 'End Heap')

pickled = hf.pickler(context['pickle'])

attachments = []
for (dirpath, dirnames, filenames) in walk(pickled['run context']['plot path']):
    for f in filenames:
        file_path = str(pickled['run context']['plot path'] + f)
        attachments.append(file_path)
    break

# add summary file to list of attachments
attachments.append(context['summary'])


# compose summary and send via email
subject = 'With Charts'

body = pprint.pformat(pickled)


hf.send_email(subject, '<pre>' + pprint.pformat(pickled) + '</pre>', version_list_html,attachments, context)
